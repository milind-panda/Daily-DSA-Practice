# %%
for i in range(0,4):
  for j in range(0,4):
    print("*",end=(" "))
  print("")
# Out:
# * * * *
# * * * *
# * * * *
# * * * *

# %%
for i in range(0,4):
  for j in range(0,i):
    print(j,end=(" "))
  print("")
# Out:
# 0
# 0 1
# 0 1 2

# %%
for i in range(0,4):
  for j in range(0,i):
    print("*",end=(" "))
  print("")
# Out:
# *
# * *
# * * *
